# %%
def divide_numbers(a, b):
    try:
        return a / b

    except ValueError:
        return "insert only integers and floats"

    except TypeError:
        return "insert only integers and floats"

    except ZeroDivisionError:
        return "number can not be divisible by zero"


result = divide_numbers(4, 0)

print(result)
# Out:
# number can not be divisible by zero
